# %% [markdown]
# # 03 章 / 第 3 节 · GRPO:复现 DeepSeek-R1 数学题对齐(迷你版)
#
# ## 学习目标
# - 理解 GRPO 与 PPO 的差异:group baseline、去掉 value model
# - 用 GSM8K-zh 小子集 + 规则化 reward(答对/格式对)
# - 跑出 reward 曲线 + 推理样例,看 chain-of-thought 是否涌现
#
# ## 对应八股
# `liguodongiot/llm-action`:**llm-interview/llm-rlhf.md (GRPO) + llm-alignment/**(见 `docs/与llm-action八股对照.md`)

# %% [markdown]
# ## 1. 概念背景
#
# > TODO:用 2-3 段中文把核心概念讲清楚,允许引用 [[Slipbox/...]] 节点。

# %% [markdown]
# ## 2. 环境检查

# %%
import sys, pathlib
sys.path.insert(0, str(pathlib.Path.cwd().parent))  # 让 scripts.* 可导入
from scripts.env_check import check
check()

# %% [markdown]
# ## 3. 核心实现
#
# > TODO:关键算子手写,别全靠库。

# %%
# TODO

# %% [markdown]
# ## 4. 跑通 + 可视化
#
# > TODO:loss 曲线 / 显存 / 吞吐数字现场跑出来。

# %%
# TODO

# %% [markdown]
# ## 5. 踩坑记录
#
# > TODO:遇到的 OOM / 版本冲突 / 配置 bug,写在这里。

# %% [markdown]
# ## 6. 延伸阅读
#
# - [[Slipbox/grpo-vs-ppo]]
# - [[Slipbox/deepseek-r1-recipe]]
# - 论文:`/paper fetch 2402.03300` (DeepSeekMath / GRPO)
