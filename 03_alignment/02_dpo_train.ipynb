# %% [markdown]
# # 03 章 / 第 2 节 · TRL DPOTrainer 跑中文偏好对齐
#
# ## 学习目标
# - 准备中文偏好数据(chosen / rejected)
# - 用 TRL DPOTrainer + 第 02 章 SFT 后模型作为 SFT-init
# - 理解 reference model 复用、beta 参数怎么调
#
# ## 对应八股
# `liguodongiot/llm-action`:**llm-interview/llm-rlhf.md**(见 `docs/与llm-action八股对照.md`)

# %% [markdown]
# ## 1. 概念背景
#
# > TODO:用 2-3 段中文把核心概念讲清楚,允许引用 [[Slipbox/...]] 节点。

# %% [markdown]
# ## 2. 环境检查

# %%
import sys, pathlib
sys.path.insert(0, str(pathlib.Path.cwd().parent))  # 让 scripts.* 可导入
from scripts.env_check import check
check()

# %% [markdown]
# ## 3. 核心实现
#
# > TODO:关键算子手写,别全靠库。

# %%
# TODO

# %% [markdown]
# ## 4. 跑通 + 可视化
#
# > TODO:loss 曲线 / 显存 / 吞吐数字现场跑出来。

# %%
# TODO

# %% [markdown]
# ## 5. 踩坑记录
#
# > TODO:遇到的 OOM / 版本冲突 / 配置 bug,写在这里。

# %% [markdown]
# ## 6. 延伸阅读
#
# - [[Slipbox/dpo-vs-ppo-vs-rlhf]]
# - [TRL DPOTrainer](https://huggingface.co/docs/trl/dpo_trainer)
