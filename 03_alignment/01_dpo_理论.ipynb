# %% [markdown]
# # 03 章 / 第 1 节 · DPO 理论:Bradley-Terry → DPO loss 推导
#
# ## 学习目标
# - 复习 RLHF / PPO 思路,理解为什么要 DPO
# - 从 Bradley-Terry 偏好模型一步步推到 DPO loss
# - 画 reward implicit / chosen-rejected margin 直观图
#
# ## 对应八股
# `liguodongiot/llm-action`:**llm-interview/llm-rlhf.md (DPO 节)**(见 `docs/与llm-action八股对照.md`)

# %% [markdown]
# ## 1. 概念背景
#
# > TODO:用 2-3 段中文把核心概念讲清楚,允许引用 [[Slipbox/...]] 节点。

# %% [markdown]
# ## 2. 环境检查

# %%
import sys, pathlib
sys.path.insert(0, str(pathlib.Path.cwd().parent))  # 让 scripts.* 可导入
from scripts.env_check import check
check()

# %% [markdown]
# ## 3. 核心实现
#
# > TODO:关键算子手写,别全靠库。

# %%
# TODO

# %% [markdown]
# ## 4. 跑通 + 可视化
#
# > TODO:loss 曲线 / 显存 / 吞吐数字现场跑出来。

# %%
# TODO

# %% [markdown]
# ## 5. 踩坑记录
#
# > TODO:遇到的 OOM / 版本冲突 / 配置 bug,写在这里。

# %% [markdown]
# ## 6. 延伸阅读
#
# - [[Slipbox/dpo-derivation]]
# - 论文:`/paper fetch 2305.18290` (DPO)
