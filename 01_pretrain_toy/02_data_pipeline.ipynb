# %% [markdown]
# # 01 章 / 第 2 节 · 数据流:streaming + sequence packing
#
# ## 学习目标
# - 用 `datasets` 加载 TinyStories-zh 或 wiki-zh streaming
# - 实现 sequence packing,把短样本拼成定长 chunk,GPU 利用率拉满
# - 理解 dataloader 的 batch / shuffle / num_workers 取舍
#
# ## 对应八股
# `liguodongiot/llm-action`:**llm-data-engineering/**(见 `docs/与llm-action八股对照.md`)

# %% [markdown]
# ## 1. 概念背景
#
# > TODO:用 2-3 段中文把核心概念讲清楚,允许引用 [[Slipbox/...]] 节点。

# %% [markdown]
# ## 2. 环境检查

# %%
import sys, pathlib
sys.path.insert(0, str(pathlib.Path.cwd().parent))  # 让 scripts.* 可导入
from scripts.env_check import check
check()

# %% [markdown]
# ## 3. 核心实现
#
# > TODO:关键算子手写,别全靠库。

# %%
# TODO

# %% [markdown]
# ## 4. 跑通 + 可视化
#
# > TODO:loss 曲线 / 显存 / 吞吐数字现场跑出来。

# %%
# TODO

# %% [markdown]
# ## 5. 踩坑记录
#
# > TODO:遇到的 OOM / 版本冲突 / 配置 bug,写在这里。

# %% [markdown]
# ## 6. 延伸阅读
#
# - [[Slipbox/sequence-packing]]
# - [datasets 文档 · streaming](https://huggingface.co/docs/datasets/stream)
