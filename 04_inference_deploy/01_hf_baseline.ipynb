# %% [markdown]
# # 04 章 / 第 1 节 · HuggingFace baseline:transformers.generate
#
# ## 学习目标
# - 用 `.generate()` 跑通推理,出基线吞吐 / 延迟
# - 理解 KV cache 是什么、prefill vs decode 阶段
# - 对比 use_cache=True/False 的延迟差异
#
# ## 对应八股
# `liguodongiot/llm-action`:**llm-inference/**(见 `docs/与llm-action八股对照.md`)

# %% [markdown]
# ## 1. 概念背景
#
# > TODO:用 2-3 段中文把核心概念讲清楚,允许引用 [[Slipbox/...]] 节点。

# %% [markdown]
# ## 2. 环境检查

# %%
import sys, pathlib
sys.path.insert(0, str(pathlib.Path.cwd().parent))  # 让 scripts.* 可导入
from scripts.env_check import check
check()

# %% [markdown]
# ## 3. 核心实现
#
# > TODO:关键算子手写,别全靠库。

# %%
# TODO

# %% [markdown]
# ## 4. 跑通 + 可视化
#
# > TODO:loss 曲线 / 显存 / 吞吐数字现场跑出来。

# %%
# TODO

# %% [markdown]
# ## 5. 踩坑记录
#
# > TODO:遇到的 OOM / 版本冲突 / 配置 bug,写在这里。

# %% [markdown]
# ## 6. 延伸阅读
#
# - [[Slipbox/kv-cache-basics]]
# - [[Slipbox/prefill-decode-stages]]
