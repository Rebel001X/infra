# %% [markdown]
# # 04 章 / 第 1 节 · 用 SmolTalk-zh 注入对话格式
#
# ## 学习目标
# - 理解 base vs midtrain vs SFT 三阶段的角色
# - 拉 SmolTalk(英文)+ 选一份中文对话数据(Belle / Firefly)
# - 在 Qwen2.5-1.5B base 上跑 ~2k 步 midtrain,只学格式不学内容
# - 对比 midtrain 前后:让模型生成 `<|im_start|>assistant` 后的内容,看格式是否正确
#
# ## 对应八股
# `liguodongiot/llm-action`:**暂无对应八股(2025+ 新概念,引用 nanochat)**(见 `docs/与llm-action八股对照.md`)

# %% [markdown]
# ## 1. 概念背景
#
# > TODO:用 2-3 段中文把核心概念讲清楚,允许引用 [[Slipbox/...]] 节点。

# %% [markdown]
# ## 2. 环境检查

# %%
import sys, pathlib
sys.path.insert(0, str(pathlib.Path.cwd().parent))
from scripts.env_check import check
check()

# %% [markdown]
# ## 3. 核心实现
#
# > TODO:关键算子手写,别全靠库。

# %%
# TODO

# %% [markdown]
# ## 4. 跑通 + 可视化
#
# > TODO:loss 曲线 / 显存 / 吞吐数字现场跑出来。

# %%
# TODO

# %% [markdown]
# ## 5. 踩坑记录
#
# > TODO:遇到的 OOM / 版本冲突 / 配置 bug,写在这里。

# %% [markdown]
# ## 6. 延伸阅读
#
# - [Karpathy nanochat midtrain stage](https://github.com/karpathy/nanochat)
# - [[Slipbox/base-midtrain-sft-stages]]
