# %% [markdown]
# # 08 章 / 第 3 节 · 推测解码(Speculative Decoding):draft + target 模型加速
#
# ## 学习目标
# - 理解 speculative decoding:用小模型起草、大模型验证,正确就接受、错了就 reject
# - Qwen2.5-0.5B(draft)+ Qwen2.5-1.5B(target)演示,看吞吐提升
# - 对比 greedy / sampling 两种 acceptance 策略
#
# ## 对应八股
# `liguodongiot/llm-action`:**llm-inference/(推测解码节)**(见 `docs/与llm-action八股对照.md`)

# %% [markdown]
# ## 1. 概念背景
#
# > TODO:用 2-3 段中文把核心概念讲清楚,允许引用 [[Slipbox/...]] 节点。

# %% [markdown]
# ## 2. 环境检查

# %%
import sys, pathlib
sys.path.insert(0, str(pathlib.Path.cwd().parent))
from scripts.env_check import check
check()

# %% [markdown]
# ## 3. 核心实现
#
# > TODO:关键算子手写,别全靠库。

# %%
# TODO

# %% [markdown]
# ## 4. 跑通 + 可视化
#
# > TODO:loss 曲线 / 显存 / 吞吐数字现场跑出来。

# %%
# TODO

# %% [markdown]
# ## 5. 踩坑记录
#
# > TODO:遇到的 OOM / 版本冲突 / 配置 bug,写在这里。

# %% [markdown]
# ## 6. 延伸阅读
#
# - 论文:`/paper fetch 2302.01318` (Fast Inference from Transformers via Speculative Decoding)
# - [[Slipbox/speculative-decoding]]
