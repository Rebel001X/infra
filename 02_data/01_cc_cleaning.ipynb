# %% [markdown]
# # 02 章 / 第 1 节 · CommonCrawl 微缩子集清洗(datatrove pipeline)
#
# ## 学习目标
# - 拉一个 50MB 级的 CC 子集(or HuggingFaceFW/fineweb-edu 抽样)
# - 用 `datatrove` 跑 fastText 语言识别 + URL 黑名单 + Gopher 质量过滤
# - 对比清洗前后样本数 / 平均长度 / 语种分布
#
# ## 对应八股
# `liguodongiot/llm-action`:**llm-data-engineering/**(见 `docs/与llm-action八股对照.md`)

# %% [markdown]
# ## 1. 概念背景
#
# > TODO:用 2-3 段中文把核心概念讲清楚,允许引用 [[Slipbox/...]] 节点。

# %% [markdown]
# ## 2. 环境检查

# %%
import sys, pathlib
sys.path.insert(0, str(pathlib.Path.cwd().parent))
from scripts.env_check import check
check()

# %% [markdown]
# ## 3. 核心实现
#
# > TODO:关键算子手写,别全靠库。

# %%
# TODO

# %% [markdown]
# ## 4. 跑通 + 可视化
#
# > TODO:loss 曲线 / 显存 / 吞吐数字现场跑出来。

# %%
# TODO

# %% [markdown]
# ## 5. 踩坑记录
#
# > TODO:遇到的 OOM / 版本冲突 / 配置 bug,写在这里。

# %% [markdown]
# ## 6. 延伸阅读
#
# - [[Slipbox/datatrove-pipeline]]
# - [FineWeb 论文 `/paper fetch 2406.17557`]
# - [CS336 A4: Data](https://stanford-cs336.github.io/spring2025/)
