# %% [markdown]
# # 02 章 / 第 2 节 · MinHash + LSH 去重
#
# ## 学习目标
# - 理解 Jaccard 相似度 → MinHash 估计 → LSH 桶哈希加速
# - 用 `datasketch` 在 01 节输出上做去重
# - 看去重前后样本数 + 几个被去重对的实例
#
# ## 对应八股
# `liguodongiot/llm-action`:**llm-data-engineering/**(见 `docs/与llm-action八股对照.md`)

# %% [markdown]
# ## 1. 概念背景
#
# > TODO:用 2-3 段中文把核心概念讲清楚,允许引用 [[Slipbox/...]] 节点。

# %% [markdown]
# ## 2. 环境检查

# %%
import sys, pathlib
sys.path.insert(0, str(pathlib.Path.cwd().parent))
from scripts.env_check import check
check()

# %% [markdown]
# ## 3. 核心实现
#
# > TODO:关键算子手写,别全靠库。

# %%
# TODO

# %% [markdown]
# ## 4. 跑通 + 可视化
#
# > TODO:loss 曲线 / 显存 / 吞吐数字现场跑出来。

# %%
# TODO

# %% [markdown]
# ## 5. 踩坑记录
#
# > TODO:遇到的 OOM / 版本冲突 / 配置 bug,写在这里。

# %% [markdown]
# ## 6. 延伸阅读
#
# - [[Slipbox/minhash-lsh-dedup]]
# - 论文:`/paper fetch 2107.06499` (Deduplicating Training Data Makes Language Models Better)
