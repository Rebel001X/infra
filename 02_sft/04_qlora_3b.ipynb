# %% [markdown]
# # 02 章 / 第 4 节 · QLoRA:4bit 把 3B 塞进 12GB
#
# ## 学习目标
# - bitsandbytes 4bit NF4 + double quant
# - 在 LoRA 之上叠加 4bit base,跑通 Qwen2.5-3B 微调
# - 对比 1.5B 全参 / 3B QLoRA 的效果与显存账
#
# ## 对应八股
# `liguodongiot/llm-action`:**llm-interview/llm-ft.md (QLoRA) + llm-compression/**(见 `docs/与llm-action八股对照.md`)

# %% [markdown]
# ## 1. 概念背景
#
# > TODO:用 2-3 段中文把核心概念讲清楚,允许引用 [[Slipbox/...]] 节点。

# %% [markdown]
# ## 2. 环境检查

# %%
import sys, pathlib
sys.path.insert(0, str(pathlib.Path.cwd().parent))  # 让 scripts.* 可导入
from scripts.env_check import check
check()

# %% [markdown]
# ## 3. 核心实现
#
# > TODO:关键算子手写,别全靠库。

# %%
# TODO

# %% [markdown]
# ## 4. 跑通 + 可视化
#
# > TODO:loss 曲线 / 显存 / 吞吐数字现场跑出来。

# %%
# TODO

# %% [markdown]
# ## 5. 踩坑记录
#
# > TODO:遇到的 OOM / 版本冲突 / 配置 bug,写在这里。

# %% [markdown]
# ## 6. 延伸阅读
#
# - [[Slipbox/qlora-nf4-double-quant]]
# - 论文:`/paper fetch 2305.14314` (QLoRA)
