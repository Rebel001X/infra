# %% [markdown]
# # 02 章 / 第 3 节 · LoRA SFT 对比
#
# ## 学习目标
# - PEFT 加 LoRA adapter,只训 ~1% 参数
# - 对比全参的训练时间 / 显存 / 效果
# - 理解 r、alpha、target_modules 怎么选
#
# ## 对应八股
# `liguodongiot/llm-action`:**llm-interview/llm-ft.md (LoRA 章)**(见 `docs/与llm-action八股对照.md`)

# %% [markdown]
# ## 1. 概念背景
#
# > TODO:用 2-3 段中文把核心概念讲清楚,允许引用 [[Slipbox/...]] 节点。

# %% [markdown]
# ## 2. 环境检查

# %%
import sys, pathlib
sys.path.insert(0, str(pathlib.Path.cwd().parent))  # 让 scripts.* 可导入
from scripts.env_check import check
check()

# %% [markdown]
# ## 3. 核心实现
#
# > TODO:关键算子手写,别全靠库。

# %%
# TODO

# %% [markdown]
# ## 4. 跑通 + 可视化
#
# > TODO:loss 曲线 / 显存 / 吞吐数字现场跑出来。

# %%
# TODO

# %% [markdown]
# ## 5. 踩坑记录
#
# > TODO:遇到的 OOM / 版本冲突 / 配置 bug,写在这里。

# %% [markdown]
# ## 6. 延伸阅读
#
# - [[Slipbox/lora-r-alpha-target-modules]]
# - 论文:`/paper fetch 2106.09685` (LoRA)
