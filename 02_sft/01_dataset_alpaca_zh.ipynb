# %% [markdown]
# # 02 章 / 第 1 节 · SFT 数据:Alpaca-zh + chat template + 损失 mask
#
# ## 学习目标
# - 理解 ChatML 格式和 Qwen2.5 chat template
# - 把 Alpaca 中文数据应用 template,做出可训样本
# - 正确 mask 掉 prompt 部分的 loss,只在 response 上学习
#
# ## 对应八股
# `liguodongiot/llm-action`:**llm-interview/llm-ft.md (数据章)**(见 `docs/与llm-action八股对照.md`)

# %% [markdown]
# ## 1. 概念背景
#
# > TODO:用 2-3 段中文把核心概念讲清楚,允许引用 [[Slipbox/...]] 节点。

# %% [markdown]
# ## 2. 环境检查

# %%
import sys, pathlib
sys.path.insert(0, str(pathlib.Path.cwd().parent))  # 让 scripts.* 可导入
from scripts.env_check import check
check()

# %% [markdown]
# ## 3. 核心实现
#
# > TODO:关键算子手写,别全靠库。

# %%
# TODO

# %% [markdown]
# ## 4. 跑通 + 可视化
#
# > TODO:loss 曲线 / 显存 / 吞吐数字现场跑出来。

# %%
# TODO

# %% [markdown]
# ## 5. 踩坑记录
#
# > TODO:遇到的 OOM / 版本冲突 / 配置 bug,写在这里。

# %% [markdown]
# ## 6. 延伸阅读
#
# - [[Slipbox/chat-template-and-loss-mask]]
# - [Qwen2.5 chat template 源](https://huggingface.co/Qwen/Qwen2.5-1.5B-Instruct/blob/main/tokenizer_config.json)
