# %% [markdown]
# # 07 章 / 第 2 节 · mini-DDP:torchrun + AllReduce
#
# ## 学习目标
# - 用 `torchrun --nproc_per_node=2`(单机 2 GPU 或 CPU 多进程)启动一个 DDP
# - 理解 DDP 三件套:DistributedSampler / DDP wrapper / barrier
# - 手写一次 AllReduce(scatter-reduce + all-gather)
# - 对比单卡 vs DDP 的 step 时间和 batch effective size
#
# ## 对应八股
# `liguodongiot/llm-action`:**llm-interview/llm-train.md (分布式) + ai-infra/通信/**(见 `docs/与llm-action八股对照.md`)

# %% [markdown]
# ## 1. 概念背景
#
# > TODO:用 2-3 段中文把核心概念讲清楚,允许引用 [[Slipbox/...]] 节点。

# %% [markdown]
# ## 2. 环境检查

# %%
import sys, pathlib
sys.path.insert(0, str(pathlib.Path.cwd().parent))
from scripts.env_check import check
check()

# %% [markdown]
# ## 3. 核心实现
#
# > TODO:关键算子手写,别全靠库。

# %%
# TODO

# %% [markdown]
# ## 4. 跑通 + 可视化
#
# > TODO:loss 曲线 / 显存 / 吞吐数字现场跑出来。

# %%
# TODO

# %% [markdown]
# ## 5. 踩坑记录
#
# > TODO:遇到的 OOM / 版本冲突 / 配置 bug,写在这里。

# %% [markdown]
# ## 6. 延伸阅读
#
# - [[Slipbox/ddp-vs-fsdp-vs-pp]]
# - [[Slipbox/allreduce-ring-tree]]
# - [PyTorch DDP 文档](https://pytorch.org/docs/stable/notes/ddp.html)
