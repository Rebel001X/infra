# %% [markdown]
# # 07 章 / 第 3 节 · mini-FSDP:参数分片 + sharded optimizer
#
# ## 学习目标
# - 理解 FSDP / ZeRO-3 的核心:把参数/梯度/优化器 state 分到所有 rank 上
# - 在 mock 2-rank 环境跑 FSDP,看显存峰值降到 DDP 的 1/N
# - 对比 ZeRO-1/2/3 的取舍
#
# ## 对应八股
# `liguodongiot/llm-action`:**llm-interview/llm-train.md (FSDP/ZeRO)**(见 `docs/与llm-action八股对照.md`)

# %% [markdown]
# ## 1. 概念背景
#
# > TODO:用 2-3 段中文把核心概念讲清楚,允许引用 [[Slipbox/...]] 节点。

# %% [markdown]
# ## 2. 环境检查

# %%
import sys, pathlib
sys.path.insert(0, str(pathlib.Path.cwd().parent))
from scripts.env_check import check
check()

# %% [markdown]
# ## 3. 核心实现
#
# > TODO:关键算子手写,别全靠库。

# %%
# TODO

# %% [markdown]
# ## 4. 跑通 + 可视化
#
# > TODO:loss 曲线 / 显存 / 吞吐数字现场跑出来。

# %%
# TODO

# %% [markdown]
# ## 5. 踩坑记录
#
# > TODO:遇到的 OOM / 版本冲突 / 配置 bug,写在这里。

# %% [markdown]
# ## 6. 延伸阅读
#
# - 论文:`/paper fetch 1910.02054` (ZeRO)
# - [PyTorch FSDP 教程](https://pytorch.org/tutorials/intermediate/FSDP_tutorial.html)
